# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = 'SN.dat'
SNdata= np.loadtxt(data, usecols=(1,2,3))
z = SNdata[:,0].flatten()

mu = SNdata[:,1].flatten()

sigma = SNdata[:,2].flatten()

# %%
z
# Out:
# array([ 0.03 ,  0.04 ,  0.05 ,  0.014,  0.033,  0.056,  0.014,  0.017,
#         0.018,  0.026,  0.026,  0.036,  0.043,  0.045,  0.046,  0.058,
#         0.061,  0.063,  0.075,  0.079,  0.088,  0.101,  0.018,  0.025,
#         0.028,  0.049,  0.05 ,  0.052,  0.071,  0.016,  0.024,  0.029,
#         0.036,  0.051,  0.089,  0.478,  0.021,  0.011,  0.015,  0.049,
#         0.465,  0.498,  0.4  ,  0.615,  0.48 ,  0.45 ,  0.388,  0.053,
#         0.067,  0.3  ,  0.23 ,  0.425,  0.62 ,  0.57 ,  0.3  ,  0.38 ,
#         0.43 ,  0.008,  0.016,  0.016,  0.007,  0.027,  0.034,  0.124,
#         0.57 ,  0.49 ,  0.495,  0.828,  0.45 ,  0.43 ,  0.024,  0.24 ,
#         0.16 ,  0.538,  0.86 ,  0.778,  0.508,  0.44 ,  0.518,  0.42 ,
#         0.334,  0.44 ,  0.5  ,  0.01 ,  0.013,  0.016,  0.017,  0.029,
#         0.58 ,  0.526,  0.172,  0.18 ,  0.374,  0.472,  0.43 ,  0.657,
#         0.32 ,  0.579,  0.45 ,  0.581,  0.416,  0.83 ,  0.97 ,  0.497,
# ...

# %%
plt.figure(figsize=(20,12))

plt.errorbar(z,mu, yerr=sigma, linestyle= "None", marker= "o")
plt.grid(1)
